# %% [markdown]
# <a href="https://colab.research.google.com/github/GeetAvaneesh/Exploratory-Data-Analytics-project-on-smoking-data-set-22BDS0343/blob/main/22BDS0343_EDA_Theory_GeetAvaneesh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# we have a data set  about smoking lets explore the dat set and see what conclusion we can reach

# %%
# libraries
import pandas as pd
import numpy as np

# %%
# getting teh csv file into colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0cbf6abb-d8e4-42ca-b414-1f069f4d4838" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cbf6abb-d8e4-42ca-b414-1f069f4d4838">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('smoking.csv')

# %%
df
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
# display first n rows
df.head(10)
# Out:
#    rownames  gender  age marital_status highest_qualification nationality  \
# 0         1    Male   38       Divorced      No Qualification     British
# 1         2  Female   42         Single      No Qualification     British
# 2         3    Male   40        Married                Degree     English
# 3         4  Female   40        Married                Degree     English
# 4         5  Female   39        Married          GCSE/O Level     British
# 5         6  Female   37        Married          GCSE/O Level     British
# 6         7    Male   53        Married                Degree     British
# 7         8    Male   44         Single                Degree     English
# 8         9    Male   40         Single              GCSE/CSE     English
# 9        10  Female   41        Married      No Qualification     English
#
#   ethnicity      gross_income     region smoke  amt_weekends  amt_weekdays  \
# 0     White    2,600 to 5,200  The North    No           NaN           NaN
# ...

# %%
# if we want to number of smokers/nonsmokers
df['smoke'].value_counts()
# this will give the count of occurence of each uniqe value in the column smoke
# Out:
# smoke
# No     1270
# Yes     421
# Name: count, dtype: int64

# %%
# so we can see here that in this data set there are 421 smokers and 1270 smokers

# %%
# to get an overview about the entire data set
df.describe()
# Out:
#           rownames          age  amt_weekends  amt_weekdays
# count  1691.000000  1691.000000    421.000000    421.000000
# mean    846.000000    49.836192     16.410926     13.750594
# std     488.293969    18.736851      9.892988      9.388292
# min       1.000000    16.000000      0.000000      0.000000
# 25%     423.500000    34.000000     10.000000      7.000000
# 50%     846.000000    48.000000     15.000000     12.000000
# 75%    1268.500000    65.500000     20.000000     20.000000
# max    1691.000000    97.000000     60.000000     55.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691 entries, 0 to 1690
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   rownames               1691 non-null   int64
#  1   gender                 1691 non-null   object
#  2   age                    1691 non-null   int64
#  3   marital_status         1691 non-null   object
#  4   highest_qualification  1691 non-null   object
#  5   nationality            1691 non-null   object
#  6   ethnicity              1691 non-null   object
#  7   gross_income           1691 non-null   object
#  8   region                 1691 non-null   object
#  9   smoke                  1691 non-null   object
#  10  amt_weekends           421 non-null    float64
#  11  amt_weekdays           421 non-null    float64
#  12  type                   421 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 171.9+ KB

# %%
# we can perform the reshaping of the data set aking the columns as rows using:
pivoted = df.T
pivoted.columns = df.index.astype(str)

# %%
pivoted
# Out:
#                                       0                 1                 2  \
# rownames                              1                 2                 3
# gender                             Male            Female              Male
# age                                  38                42                40
# marital_status                 Divorced            Single           Married
# highest_qualification  No Qualification  No Qualification            Degree
# nationality                     British           British           English
# ethnicity                         White             White             White
# gross_income             2,600 to 5,200       Under 2,600  28,600 to 36,400
# region                        The North         The North         The North
# smoke                                No               Yes                No
# amt_weekends                        NaN              12.0               NaN
# ...

# %%
# we can also pivot the data frame using:
Stack_data= df.stack()

# %%
Stack_data
# Out:
# 0     rownames                                1
#       gender                               Male
#       age                                    38
#       marital_status                   Divorced
#       highest_qualification    No Qualification
#                                      ...
# 1690  nationality                      Scottish
#       ethnicity                           White
#       gross_income             10,400 to 15,600
#       region                           Scotland
#       smoke                                  No
# Length: 18173, dtype: object

# %%
df.unstack()
# Out:
# rownames  0                 1
#           1                 2
#           2                 3
#           3                 4
#           4                 5
#                      ...
# type      1686            NaN
#           1687    Hand-Rolled
#           1688            NaN
#           1689        Packets
#           1690            NaN
# Length: 21983, dtype: object

# %%
#  data cleaning,duplication and filtering
df
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
df.duplicated()
# will tell which rows have been duplicated exactly same
# the first unq row returns false every copied row after 1st row shows true
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1686    False
# 1687    False
# 1688    False
# 1689    False
# 1690    False
# Length: 1691, dtype: bool

# %%
# looks like we dont have much duplicate rows
# lets remove the duplicate if any
new_df = df.drop_duplicates()
new_df
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
# the new df also have 1691 rows which is same as the old df that means there are no duplicates

# %%
# replacing data in data frame
# example code given in notes:
#replaceFrame.replace(to_replace =[-786, 0], value= [np.nan, 2])
# we can use this to replace the NAN values bu fr this we need to manually give some specific data that will replace the gaps

# %%
# too see how many null values are present this wont give a count but will give whether it is true or false

# %%
df.isnull()
# Out:
#       rownames  gender    age  marital_status  highest_qualification  \
# 0        False   False  False           False                  False
# 1        False   False  False           False                  False
# 2        False   False  False           False                  False
# 3        False   False  False           False                  False
# 4        False   False  False           False                  False
# ...        ...     ...    ...             ...                    ...
# 1686     False   False  False           False                  False
# 1687     False   False  False           False                  False
# 1688     False   False  False           False                  False
# 1689     False   False  False           False                  False
# 1690     False   False  False           False                  False
#
#       nationality  ethnicity  gross_income  region  smoke  amt_weekends  \
# ...

# %%
df.notnull()
# will tell true if it is not null
# Out:
#       rownames  gender   age  marital_status  highest_qualification  \
# 0         True    True  True            True                   True
# 1         True    True  True            True                   True
# 2         True    True  True            True                   True
# 3         True    True  True            True                   True
# 4         True    True  True            True                   True
# ...        ...     ...   ...             ...                    ...
# 1686      True    True  True            True                   True
# 1687      True    True  True            True                   True
# 1688      True    True  True            True                   True
# 1689      True    True  True            True                   True
# 1690      True    True  True            True                   True
#
#       nationality  ethnicity  gross_income  region  smoke  amt_weekends  \
# 0            True       True          True    True   True         False
# ...

# %%
# to get count of NAN values
df.isnull().sum()
# Out:
# rownames                    0
# gender                      0
# age                         0
# marital_status              0
# highest_qualification       0
# nationality                 0
# ethnicity                   0
# gross_income                0
# region                      0
# smoke                       0
# amt_weekends             1270
# amt_weekdays             1270
# type                     1270
# dtype: int64

# %%
# so we can see that the columns amt_weekends,amt_weekdays and type have 1270 NaN values but the other
# columns have 0 NaN values

# %%
# if we want to find the number of values that are taken into count ie; not NaN
df.count()
# Out:
# rownames                 1691
# gender                   1691
# age                      1691
# marital_status           1691
# highest_qualification    1691
# nationality              1691
# ethnicity                1691
# gross_income             1691
# region                   1691
# smoke                    1691
# amt_weekends              421
# amt_weekdays              421
# type                      421
# dtype: int64

# %%
# if we want to use df.dropna() it will delete the entire row even if there is a single null value
# if we use df.dropna(how='all') it will delete the row only if alll the values in that row are null
# if we want to filter the NaN values through a column we need to use df.dropna(how='all',axis=1)
# if we want to filter the NaN values by mentioning a minimum value then if the row has that minimum number of Nan value it gets removed
# df.dropna(thresh=min,axis=1)

# %%
# lets perform these on duplicates
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()

# %%
df1.dropna()
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 1            2  Female   42         Single      No Qualification     British
# 6            7    Male   53        Married                Degree     British
# 8            9    Male   40         Single              GCSE/CSE     English
# 9           10  Female   41        Married      No Qualification     English
# 20          21  Female   34        Married              GCSE/CSE     British
# ...        ...     ...  ...            ...                   ...         ...
# 1674      1675  Female   31         Single          GCSE/O Level    Scottish
# 1680      1681    Male   24         Single      No Qualification    Scottish
# 1683      1684    Male   35        Married      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1689      1690  Female   51        Married      No Qualification     English
#
# ...

# %%
# we can see that by using the aboe method we deleted 1290 rows

# %%
df2.dropna(how='all')
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
# so there are no rows where all the values are null

# %%
df3.dropna(axis=1)
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
# there are three columns with atleast 1 null value

# %%
df4.dropna(thresh=5,axis=1)
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
# lets fill the Nan values with 0
# lets make an duplicate data frame for that
df_fillzero = df.copy()
df_copy = df.copy()
df_fillzero.fillna(0)
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
df_fillzero
# this will still have NaN but not 0 since fillna will create a copy and fill but not rewrite into the orginal one
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
# lets calculate the mean of amout of ciggerets consumed on weekdays and weekend and accordinly fill the NaN values

# %%
weekends_mean = df['amt_weekends'].mean(skipna=True)
weekdays_mean = df['amt_weekdays'].mean(skipna=True)

# %%
print(weekends_mean)
print(weekdays_mean)
# Out:
# 16.410926365795724
# 13.750593824228028

# %%
df['amt_weekends'].fillna(weekends_mean,inplace=True)
df['amt_weekdays'].fillna(weekdays_mean,inplace=True)
# Out:
# /tmp/ipython-input-423653465.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['amt_weekends'].fillna(weekends_mean,inplace=True)
# /tmp/ipython-input-423653465.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
# we can see that the amt_weekends and weekdays columns have been filed with respective means

# %%
# but for the type column we cant do this cause it is a Nominal type data so it would be best to replace it with label with highest count
highest_type =df['type'].value_counts().idxmax()

# %%
highest_type
# Out:
# 'Packets'

# %%
# so packets is the most consumed type of cigerates
# so
df['type'].fillna(highest_type,inplace=True)
# Out:
# /tmp/ipython-input-2889143284.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['type'].fillna(highest_type,inplace=True)

# %%
df
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
df.isnull().sum()
# to ensure if there are anymore null  values
# Out:
# rownames                 0
# gender                   0
# age                      0
# marital_status           0
# highest_qualification    0
# nationality              0
# ethnicity                0
# gross_income             0
# region                   0
# smoke                    0
# amt_weekends             0
# amt_weekdays             0
# type                     0
# dtype: int64

# %%
# fill na values using backwoard and forward filling
copy2 = df_copy.copy()
df_copy.fillna(method='bfill')
# Out:
# /tmp/ipython-input-2043624281.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_copy.fillna(method='bfill')
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# ...

# %%
copy2.fillna(method='bfill')
# Out:
# /tmp/ipython-input-3945145057.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   copy2.fillna(method='bfill')
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# ...

# %%
# lets create bins of age nd categorize the ppl based on their age and create a new column based in that
age_bins = [12, 19, 26, 60, 100]
age_labels = ['Kid', 'Teen', 'middle-aged', 'Senior citizen']
df['age_group'] = pd.cut(df['age'], bins=age_bins, labels=age_labels)

# %%
df.head(5)
# Out:
#    rownames  gender  age marital_status highest_qualification nationality  \
# 0         1    Male   38       Divorced      No Qualification     British
# 1         2  Female   42         Single      No Qualification     British
# 2         3    Male   40        Married                Degree     English
# 3         4  Female   40        Married                Degree     English
# 4         5  Female   39        Married          GCSE/O Level     British
#
#   ethnicity      gross_income     region smoke  amt_weekends  amt_weekdays  \
# 0     White    2,600 to 5,200  The North    No     16.410926     13.750594
# 1     White       Under 2,600  The North   Yes     12.000000     12.000000
# 2     White  28,600 to 36,400  The North    No     16.410926     13.750594
# 3     White  10,400 to 15,600  The North    No     16.410926     13.750594
# 4     White    2,600 to 5,200  The North    No     16.410926     13.750594
#
#       type    age_group
# 0  Packets  middle-aged
# ...

# %%
# lets categorize or bin the smokers based on their intensity or amount of smoke on weekdays and weekends
weekend_bins = [0, 5, 10, 25, 60]
weekend_labels = ['non-smoker', 'Light', 'Moderate', 'Heavy']
df['weekend_intensity'] = pd.cut(df['amt_weekends'], bins=weekend_bins, labels=weekend_labels)
weekday_bins = [0, 5, 10, 25, 60]
weekday_labels = ['non-smoker', 'Light', 'Moderate', 'Heavy']
df['weekdays_intensity'] = pd.cut(df['amt_weekdays'], bins=weekend_bins, labels=weekend_labels)

# %%
df
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
# outlier identification

# %%
weekends_outliers = df[np.abs(df['amt_weekends']) > 50]
print(weekends_outliers[['gender','amt_weekends','amt_weekdays']])
# we are setting a value of 40 as a threshold as 40 ciggeretes in just 2 days seems unrealistic and can affect our analysis
# Out:
#       gender  amt_weekends  amt_weekdays
# 1182    Male          60.0          40.0
# 1659  Female          60.0          30.0

# %%
# so we have 2 outliers according to our assumption of taking a threshold of 50 ciggerets for weekends

# %%
# module 3

# %%
# univariate analysis
# central tendancy dispersion
# IQR and standard deviation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data cleaning
pd.isna(df).any()
# Out:
# rownames                 False
# gender                   False
# age                      False
# marital_status           False
# highest_qualification    False
# nationality              False
# ethnicity                False
# gross_income             False
# region                   False
# smoke                    False
# amt_weekends             False
# amt_weekdays             False
# type                     False
# age_group                False
# weekend_intensity         True
# weekdays_intensity        True
# dtype: bool

# %%
# no null values so we can proceed with our analysis and make efective visualizations

# %%
# lets strip any leading or trailing spaces if they exist for the column names

df.columns = df.columns.str.strip()

# check for non-numeric values in columns which are supposed to have numeric data

print("amt_weekends value counts for numeric check:")
print(df['amt_weekends'].astype(str).str.isnumeric().value_counts())

print("\namt_weekdays value counts for numeric check:")
print(df['amt_weekdays'].astype(str).str.isnumeric().value_counts())

print("\nAge non-numeric check:")
print(df['age'].astype(str).str.isnumeric().value_counts())
# Out:
# amt_weekends value counts for numeric check:
# amt_weekends
# False    1691
# Name: count, dtype: int64
#
# amt_weekdays value counts for numeric check:
# amt_weekdays
# False    1691
# Name: count, dtype: int64
#
# Age non-numeric check:
# age
# True    1691
# Name: count, dtype: int64

# %%
# we can see that the isnumeric test for the columns 'amt_weekdays' and 'amt_weekends' fail as they are of float data type and isnumeric works only for integers which we can see for the column age
df.dtypes
# Out:
# rownames                    int64
# gender                     object
# age                         int64
# marital_status             object
# highest_qualification      object
# nationality                object
# ethnicity                  object
# gross_income               object
# region                     object
# smoke                      object
# amt_weekends              float64
# amt_weekdays              float64
# type                       object
# age_group                category
# weekend_intensity        category
# weekdays_intensity       category
# dtype: object

# %%
df
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
# univariate analysis for numerical columns age,mat_weekends,amt_weekdays
# at this stage i cant find any more need to clean the data or data pre processing to do
# we have replaced null values,checked for data types mismatch , we have made bins of numerical data columns
# now lets look into depth of each variable for univariate analysis ie; each column

# %%
# measures of central tendancy for numerical columns
# Measures of central tendency for age column
age_mean = df['age'].mean()
age_median = df['age'].median()
age_mode = df['age'].mode()[0]
age_var = df['age'].var()
age_stndrddev = df['age'].std()

print(" Measures of central tendancy for age column:")
print("mean: ", age_mean)
print("median: ", age_median)
print("mode: ", age_mode)
print("variance: ", age_var)
print("standard Deviation: ", age_stndrddev)
print(" ")

# Measures of central tendency for amt_weekends column
weekends_mean = df['amt_weekends'].mean()
weekends_median = df['amt_weekends'].median()
weekends_mode = df['amt_weekends'].mode()[0]
weekends_var = df['amt_weekends'].var()
weekends_stndrddev = df['amt_weekends'].std()


print("Measures of central tendancy for amt_weekends column:")
print("mean: ", weekends_mean)
print("median: ", weekends_median)
print("mode: ", weekends_mode)
print("variance: ", weekends_var)
print("standard Deviation: ", weekends_stndrddev)
print(" ")


# Measures of central tendency for amt_weekdays column
weekdays_mean = df['amt_weekdays'].mean()
weekdays_median = df['amt_weekdays'].median()
weekdays_mode = df['amt_weekdays'].mode()[0]
weekdays_var = df['amt_weekdays'].var()
weekdays_stndrddev = df['amt_weekdays'].std()

print("Measures of central tendancy for amt_weekdays column:")
print("mean: ", weekdays_mean)
print("median: ", weekdays_median)
print("mode: ", weekdays_mode)
print("variance: ", weekdays_var)
print("standard Deviation: ", weekdays_stndrddev)
print(" ")
# Out:
#  Measures of central tendancy for age column:
# mean:  49.836191602602014
# median:  48.0
# mode:  40
# variance:  351.0696006354554
# standard Deviation:  18.7368514066653
#
# Measures of central tendancy for amt_weekends column:
# mean:  16.41092636579572
# median:  16.410926365795724
# mode:  16.410926365795724
# variance:  24.323023514033988
# standard Deviation:  4.9318377420626875
#
# Measures of central tendancy for amt_weekdays column:
# mean:  13.750593824228028
# median:  13.750593824228028
# mode:  13.750593824228028
# variance:  21.90462269322126
# standard Deviation:  4.680237461200154

# %%
# nanalysis for numerical columns
import matplotlib.pyplot as plt

num_cols = ['age', 'amt_weekends', 'amt_weekdays']
for i in num_cols:
    plt.figure(figsize=(6,4))
    plt.hist(df[i], bins=10, color='lightgreen',edgecolor='black')
    plt.title(f"Histogram of {i}")
    plt.xlabel(i)
    plt.ylabel("frequency")
    plt.show()

# %%
# from these graphs we can make important observation like the age group between 30 to 40 has highest frequency
# the frequncy of amout smokes in a weekend is mostly between 10 and 20
# if we increase the number of bins in the plot we will get a deeper understanding and more precise results

# %%
# nanalysis for numerical columns
import matplotlib.pyplot as plt

num_cols = ['age', 'amt_weekends', 'amt_weekdays']
for i in num_cols:
    plt.figure(figsize=(6,4))
    plt.hist(df[i], bins=50, color='lightgreen',edgecolor='black')
    plt.title(f"Histogram of {i}")
    plt.xlabel(i)
    plt.ylabel("frequency")
    plt.show()

# %%
# now with 50 bins we can say that the age with highest frequency in this data set is 38 exactly and the highest frequent amount of smoke on weekend is 16

# %%
# lets create boxplots for these columns inorder to do check their spread and outliers

# %%
for i in num_cols:
    plt.figure(figsize=(6,4))
    plt.boxplot(df[i])
    plt.title(f"Boxplot of {i}")
    plt.ylabel(i)
    plt.show()

# %%
# from the boxplot of age we can say that age is positively skewed as the middle line or the 50th percentile is closer to bottoom of the box
# so are amt_weekends and amt_ weekdays they are also positively skewed
# for the weekends and weekdays columns there is no box only
# we now that these columns had alot of mssing values so replacing them with mean made the data too clustered there very little uniques values this led to a very small inter quartile range

# %%
# for columns that hold nominal data we can see which attribute has more occureneces using a boxplot
nominal = ['gender', 'smoke', 'marital_status', 'type','ethnicity','nationality','region']
for i in nominal:
    print(f"Occurences of {i}:")
    print(df[i].value_counts())
    print(" ")
# Out:
# Occurences of gender:
# gender
# Female    965
# Male      726
# Name: count, dtype: int64
#
# Occurences of smoke:
# smoke
# No     1270
# Yes     421
# Name: count, dtype: int64
#
# Occurences of marital_status:
# marital_status
# Married      812
# Single       427
# Widowed      223
# Divorced     161
# Separated     68
# Name: count, dtype: int64
#
# Occurences of type:
# type
# Packets                    1567
# Hand-Rolled                  72
# Both/Mainly Packets          42
# Both/Mainly Hand-Rolled      10
# Name: count, dtype: int64
#
# Occurences of ethnicity:
# ethnicity
# White      1560
# Asian        41
# Black        34
# Chinese      27
# Mixed        14
# Refused      13
# Unknown       2
# Name: count, dtype: int64
#
# Occurences of nationality:
# nationality
# English     833
# British     538
# Scottish    142
# Other        71
# Welsh        66
# Irish        23
# Refused      17
# Unknown       1
# Name: count, dtype: int64
#
# Occurences of region:
# region
# ...

# %%
# we can get information from this like
# females are more
# non smokers are more
# married people are more that explains why more occurences of people in the ages 30 to 40
# packets are most used type of ciggerets if we look at a business point of view we can come to conlusion that saes of packets of ciggerets would be good decision

# %%
for i in nominal:
    plt.figure(figsize=(6,4))
    df[i].value_counts().plot(kind='bar', color='salmon', edgecolor='black')
    plt.title(f"Bar Chart of {i}")
    plt.xlabel(i)
    plt.ylabel("count")
    plt.show()

# %%
# from the graph we can see the diferences between different categories in depth for eg in the cigarete type both/mainly rolled is very less almost negligible

# %%
# distribution plots to show the data is distributed
sns.histplot(data=df, x='age', hue='smoke', kde=True, bins=20)
plt.title("Age distribution smokers vs non-smokers")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
# bivariate analysis

# %%
sns.boxplot(x="smoke", y="age", data=df)
plt.title("Age Distribution: Smokers vs Non-Smokers")
plt.show()

# %%
#we can see that mostly middle aged people are smokers

sns.countplot(x="age_group", hue="smoke", data=df)
plt.title("Smoking Status by Age Group")
plt.xticks(rotation=45)
plt.show()

# %%
# in order to do a scatter plot to find the correlation between smoke and age i need to convert the smoke to numeric data so i will convert the yes and no to 0 and 1

# %%
# coorealtion
df["smoke_num"] = df["smoke"].map({"No": 0, "Yes": 1})
corr = np.corrcoef(df["age"], df["smoke_num"])[0, 1]
print("Correlation between Age and Smoking:", corr)
# Out:
# Correlation between Age and Smoking: -0.21888997429744145

# %%
# so we can see that age and smokeing has a negative correlation
# as age increases the chances of being a smoker reduces

# %%
plt.scatter(df["age"], df["smoke_num"], alpha=0.5)
plt.title("Age vs Smoking Status")
plt.xlabel("Age")
plt.ylabel("Smoking Status (0=No, 1=Yes)")
plt.show()

# %%
# we cant infer much from these scatter plot as there are very unique values
# but we get good analysis from the box plot and correlation value done previously

# %%
# relation between age and intensity of smoking on weekends
plt.scatter(df["age"], df["amt_weekends"])
plt.title("Scatter Plot: Age vs Amount Smoked on Weekends")
plt.xlabel("Age")
plt.ylabel("Amount Smoked (Weekends)")
plt.show()

# %%
# i cant derive much information from the scatter plot here

# %%
corr_age_weekends = np.corrcoef(df["age"], df["amt_weekends"])
print("Correlation Matrix:\n", corr_age_weekends)
# Out:
# Correlation Matrix:
#  [[1.         0.02524404]
#  [0.02524404 1.        ]]

# %%
# the correlation between age and amount of smoking is 0.025 which is extremely weak positive correlation
# we cant predivt the amount of smoking based on age on weekends_meanlets try the same for weekdays and try if we can find a relation

# %%
# relation between age and intensity of smoking on weekends
plt.scatter(df["age"], df["amt_weekdays"])
plt.title("Scatter Plot: Age vs Amount Smoked on Weekdays")
plt.xlabel("Age")
plt.ylabel("Amount Smoked (Weekends)")
plt.show()

# %%
# for weekdays also we can see almost same plot
corr_age_weekdays = np.corrcoef(df["age"], df["amt_weekdays"])
print("Correlation Matrix:\n", corr_age_weekdays)
# Out:
# Correlation Matrix:
#  [[1.         0.08298911]
#  [0.08298911 1.        ]]

# %%
# the coeeficient of correlation in case of weekdays is slightly more but this is also ignorable

# %%
# we can also do if there is relation between intensity of smoking on weekends and weekdays
plt.scatter(df["amt_weekdays"], df["amt_weekends"])
plt.title("Weekday vs Weekend Smoking")
plt.xlabel("Weekday Amount")
plt.ylabel("Weekend Amount")
plt.show()

# %%
# this shows a strong positive correlation
# lets find the exact amount of correlation using co-efficient of correlation

# %%
corr_weekend_weekdays = np.corrcoef(df["amt_weekdays"], df["amt_weekends"])
print("Correlation Matrix:\n", corr_weekend_weekdays)
# Out:
# Correlation Matrix:
#  [[1.         0.80205212]
#  [0.80205212 1.        ]]

# %%
# it is highly positive correlation of 0.8
# so we can tell if a person is heavy smoker on weekday he is a heavy smoker on weekend as well

# %%
# finding gender dependance on the smoking
df["gender_num"] = df["gender"].map({"Male": 0, "Female": 1})

# %%
plt.scatter(df["gender_num"], df["smoke_num"], alpha=0.5)
plt.title("Scatter Plot: Gender vs Smoking Status")
plt.xlabel("Gender (0=Male, 1=Female)")
plt.ylabel("Smoking Status (0=No, 1=Yes)")
plt.yticks([0, 1], ["No", "Yes"])
plt.xticks([0, 1], ["Male", "Female"])
plt.show()

# %%
# correlation between smoking and gender
corr_gender_smoke = np.corrcoef(df["gender_num"], df["smoke_num"])
print("Correlation Matrix:\n", corr_gender_smoke)
# Out:
# Correlation Matrix:
#  [[ 1.         -0.01727194]
#  [-0.01727194  1.        ]]

# %%
# they are very weakly related or we cant say about the smoking habit based on gender -0.01 is a very very weak negative relation

# %%
sns.boxplot(x="gender", y=df["smoke"].map({"No": 0, "Yes": 1}), data=df)
plt.title("Box Plot: Gender vs Smoking Status")
plt.ylabel("Smoking Status")
plt.show()

# %%
# there is nothing much we can infer from this box plot as well

# %%
plt.scatter(df["gender_num"], df["amt_weekdays"], alpha=0.5)
plt.title("Gender vs Smoking Intensity")
plt.xlabel("Gender (0=Male, 1=Female)")
plt.ylabel("Smoking Intensity")
plt.xticks([0, 1], ["Male", "Female"])
plt.show()

# %%
# we can say that male has more of heavy smokers

# %%
sns.boxplot(x="gender", y="amt_weekdays", data=df)
plt.title("Gender vs Smoking Intensity")
plt.ylabel("Smoking Intensity")
plt.show()

# %%
# it would be the same for weekends as well as weekend intensity adn weekdaya are highly correlated

# %%
df.head(2)
# Out:
#    rownames  gender  age marital_status highest_qualification nationality  \
# 0         1    Male   38       Divorced      No Qualification     British
# 1         2  Female   42         Single      No Qualification     British
#
#   ethnicity    gross_income     region smoke  amt_weekends  amt_weekdays  \
# 0     White  2,600 to 5,200  The North    No     16.410926     13.750594
# 1     White     Under 2,600  The North   Yes     12.000000     12.000000
#
#       type    age_group weekend_intensity weekdays_intensity  smoke_num  \
# 0  Packets  middle-aged          Moderate           Moderate          0
# 1  Packets  middle-aged          Moderate           Moderate          1
#
#    gender_num
# 0           0
# 1           1

# %%
listtt = ["ethnicity", "region", "nationality", "highest_qualification", "marital_status"]

for i in listtt:
    sns.countplot(x=i, hue="smoke", data=df)
    plt.title(f"Smoking Status by {i}")
    plt.xticks(rotation=45)
    plt.show()

# %%
# from these we can make few conclusion like
# white people have more smokers
# north region has more smokers the midlands and east anglia also have almost equal smokers
# single people tend to be more Smokers
# English  people have more smokers
# most people with no qualification tend to smoke more

# %%
# multivariate analysis

# %%
sns.pairplot(df, vars=['age', 'amt_weekends', 'amt_weekdays'], kind="reg",hue= "smoke", palette={'Yes': 'purple', 'No': 'pink'})
plt.show()

# %%
# pearson correlation
correlation = df[['age', 'amt_weekends', 'amt_weekdays']].corr(method='pearson')
print(correlation)
# Out:
#                    age  amt_weekends  amt_weekdays
# age           1.000000      0.025244      0.082989
# amt_weekends  0.025244      1.000000      0.802052
# amt_weekdays  0.082989      0.802052      1.000000

# %%
sns.heatmap(correlation, annot=True, cmap="coolwarm", xticklabels=correlation.columns, yticklabels=correlation.columns)
plt.title("Correlation Heatmap - Smoking Data")
plt.show()
# heatmap for showing correlation using colours

# %%
# we can see that most dark shade red shows more correlation
# that is 0.8 and between amount of smoke on weekdaya and weekends
# age is very correlated

# %%
# anaysing smoke with age,intensity of smokeing on ends and days
# for that we will use the numerical equavilent of smoke column
corr_smoke = df[['age', 'amt_weekends', 'amt_weekdays', 'smoke_num']].corr()
print(corr_smoke)
sns.heatmap(corr_smoke, annot=True, cmap="coolwarm")
plt.show()
# Out:
#                    age  amt_weekends  amt_weekdays     smoke_num
# age           1.000000  2.524404e-02  8.298911e-02 -2.188900e-01
# amt_weekends  0.025244  1.000000e+00  8.020521e-01 -1.399418e-16
# amt_weekdays  0.082989  8.020521e-01  1.000000e+00  8.502427e-17
# smoke_num    -0.218890 -1.399418e-16  8.502427e-17  1.000000e+00

# %%
df
# Out:
#       rownames  gender  age marital_status highest_qualification nationality  \
# 0            1    Male   38       Divorced      No Qualification     British
# 1            2  Female   42         Single      No Qualification     British
# 2            3    Male   40        Married                Degree     English
# 3            4  Female   40        Married                Degree     English
# 4            5  Female   39        Married          GCSE/O Level     British
# ...        ...     ...  ...            ...                   ...         ...
# 1686      1687    Male   22         Single      No Qualification    Scottish
# 1687      1688  Female   49       Divorced      Other/Sub Degree     English
# 1688      1689    Male   45        Married      Other/Sub Degree    Scottish
# 1689      1690  Female   51        Married      No Qualification     English
# 1690      1691    Male   31        Married                Degree    Scottish
#
# ...

# %%
# there is no much correlation with each other

# %%
# lets find out the correlation for all the columns of dataframe with each other
from scipy import stats

# %%
corr_full = df.corr(method='pearson', numeric_only=True)
corr_full
# Out:
#               rownames       age  amt_weekends  amt_weekdays     smoke_num  \
# rownames      1.000000  0.005149  2.660972e-02  2.525552e-02  5.251576e-02
# age           0.005149  1.000000  2.524404e-02  8.298911e-02 -2.188900e-01
# amt_weekends  0.026610  0.025244  1.000000e+00  8.020521e-01 -1.399418e-16
# amt_weekdays  0.025256  0.082989  8.020521e-01  1.000000e+00  8.502427e-17
# smoke_num     0.052516 -0.218890 -1.399418e-16  8.502427e-17  1.000000e+00
# gender_num   -0.066380  0.031513 -7.976098e-02 -1.028121e-01 -1.727194e-02
#
#               gender_num
# rownames       -0.066380
# age             0.031513
# amt_weekends   -0.079761
# amt_weekdays   -0.102812
# smoke_num      -0.017272
# gender_num      1.000000

# %%
sns.heatmap(corr_full,xticklabels=corr_full.columns, yticklabels=corr_full.columns)
# Out:
# <Axes: >

# %%
# to see which is most correlated pair
corr_pairs = corr_full.unstack()
corr_pairs = corr_pairs.drop(labels=[(col, col) for col in corr_full.columns]).sort_values(ascending=False)

corr_pairs = corr_pairs[~corr_pairs.index.duplicated()]

print("Highest correlated pair:")
print(corr_pairs.head(10))
# Out:
# Highest correlated pair:
# amt_weekends  amt_weekdays    0.802052
# amt_weekdays  amt_weekends    0.802052
#               age             0.082989
# age           amt_weekdays    0.082989
# rownames      smoke_num       0.052516
# smoke_num     rownames        0.052516
# gender_num    age             0.031513
# age           gender_num      0.031513
# amt_weekends  rownames        0.026610
# rownames      amt_weekends    0.026610
# dtype: float64

# %%
# from the top 10 highest correlated pairs the only one that makes sense is intensity of weekend compared to weekday

# %%
# 1D analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis
from mpl_toolkits.mplot3d import Axes3D
import ternary

# %%
num_cols = ['age', 'amt_weekdays', 'amt_weekends']

# 1-D ANALYSIS for each numeric column

for col in num_cols:
    print(f"\n--- 1-D SUMMARY statistics for {col} ---")
    print(f"Meaan     : {df[col].mean():.2f}")
    print(f"Median   : {df[col].median():.2f}")
    print(f"Mode     : {df[col].mode().iloc[0]:.2f}")
    print(f"Skewness : {skew(df[col]):.2f}")
    print(f"Kurtosis : {kurtosis(df[col]):.2f}")

    # Histogram
    plt.figure(figsize=(7,4))
    sns.histplot(df[col], bins=20, edgecolor="black", kde=False)
    plt.title(f"Histogram of {col}")
    plt.show()

    # KDE curve
    plt.figure(figsize=(7,4))
    sns.kdeplot(df[col], fill=True)
    plt.title(f"KDE curve for {col}")
    plt.show()

    # Boxplot
    plt.figure(figsize=(5,4))
    sns.boxplot(y=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

    # Cumulative Frequency
    plt.figure(figsize=(7,4))
    df[col].plot(kind="hist", cumulative=True, bins=20, edgecolor="black")
    plt.title(f"Cumulative Frequency of {col}")
    plt.show()

    # Bar plot of value counts
    plt.figure(figsize=(7,4))
    df[col].value_counts().sort_index().plot(kind="bar", color='salmon')
    plt.title(f"Bar Chart of {col}")
    plt.show()
# Out:
# --- 1-D SUMMARY statistics for age ---
# Meaan     : 49.84
# Median   : 48.00
# Mode     : 40.00
# Skewness : 0.17
# Kurtosis : -1.00
# --- 1-D SUMMARY statistics for amt_weekdays ---
# Meaan     : 13.75
# Median   : 13.75
# Mode     : 13.75
# Skewness : 2.23
# Kurtosis : 16.45
# --- 1-D SUMMARY statistics for amt_weekends ---
# Meaan     : 16.41
# Median   : 16.41
# Mode     : 16.41
# Skewness : 1.98
# Kurtosis : 16.01

# %%
# 2-D RELATIONSHIPS

for amt in ['amt_weekdays','amt_weekends']:
    plt.figure(figsize=(7,5))
    plt.scatter(df['age'], df[amt], alpha=0.6)
    plt.xlabel("Age")
    plt.ylabel(amt)
    plt.title(f"Scatter: Age vs {amt}")
    plt.show()

ct = pd.crosstab(df['gender'], df['smoke'])
sns.heatmap(ct, annot=True, fmt='d', cmap='YlGnBu')
plt.title("Heatmap: Smoking vs Gender")
plt.show()

for amt in ['amt_weekdays','amt_weekends']:
    plt.figure(figsize=(7,5))
    sns.boxplot(x='smoke', y=amt, data=df)
    plt.title(f"Boxplot: {amt} by Smoking status")
    plt.show()

sns.pairplot(df[num_cols + ['smoke']], hue='smoke')
plt.suptitle("Pairwise relations among numeric vars", y=1.02)
plt.show()

# %%
# 3-D SCATTER PLOT
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['age'], df['amt_weekdays'], df['amt_weekends'],
           c=df['smoke'].map({'Yes':'red','No':'blue'}),
           alpha=0.6)

ax.set_xlabel("Age")
ax.set_ylabel("Weekday amt")
ax.set_zlabel("Weekend amt")
ax.set_title("3-D Scatter: Age vs Weekday vs Weekend")
plt.show()

# %%
# 3-D TERNARY-STYLE PLOT
ternary_data = []
for _, row in df.sample(50, random_state=1).iterrows():
    total = row['age'] + row['amt_weekdays'] + row['amt_weekends']
    if total > 0:
        ternary_data.append( (row['age']/total,
                              row['amt_weekdays']/total,
                              row['amt_weekends']/total) )

scale = 1
fig, tax = ternary.figure(scale=scale)
tax.boundary(linewidth=2.0)
tax.gridlines(multiple=0.1, color="grey")

for p,c,f in ternary_data:
    tax.scatter([(p,c,f)], marker='o', color='purple', s=25)

tax.left_corner_label("Age", fontsize=11)
tax.right_corner_label("Weekdays", fontsize=11)
tax.top_corner_label("Weekends", fontsize=11)
tax.ticks(axis='lbr', multiple=0.1, linewidth=1)
tax.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans, AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.decomposition import PCA



data = df.copy()

num_cols = ['age', 'amt_weekdays', 'amt_weekends']

cats = ['gender', 'region']
dummies = pd.get_dummies(data[cats], drop_first=True)
X = pd.concat([data[num_cols], dummies], axis=1)

X = X.dropna()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Hierarchical clustering & Dendrogram
plt.figure(figsize=(10, 5))
link = linkage(X_scaled, method='ward')
dend = dendrogram(link, truncate_mode='level', p=5)
plt.title("hierarchical clustering)")
plt.xlabel("Points")
plt.ylabel("Distance")
plt.show()

n_clusters = 3
cluster_labels = fcluster(link, n_clusters, criterion='maxclust')
data['hier_cluster'] = cluster_labels
